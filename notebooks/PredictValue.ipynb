# %% [markdown]
# <a href="https://colab.research.google.com/github/olga-terekhova/indoor-co2-forecast/blob/main/notebooks/PredictValue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# set up paths

drive_data_dir = '/MyDrive/Data/flow-co2/data/'

drive_model_dir = '/MyDrive/Data/flow-co2/model/'
mount_dir = '/content/drive'
data_dir = mount_dir + drive_data_dir

model_dir = mount_dir+drive_model_dir

# %%
# mount data source

from google.colab import drive
drive.mount(mount_dir)
# Out:
# Mounted at /content/drive

# %%
# import libraries

import pandas as pd
import pickle

# %%
# read model from pickle

with open(model_dir+'model-regressor.pkl', 'rb') as f:
    loaded_model_dict = pickle.load(f)

# %%
# load
import joblib
clf2 = joblib.load(model_dir+'model-regressor-jl.pkl')

# %%
loaded_model_dict
# Out:
# {'model': ExtraTreesRegressor(n_estimators=200, random_state=42),
#  'feature_names': ['roll10_mean',
#   'roll10_std',
#   'roll20_mean',
#   'roll20_std',
#   'roll50_mean',
#   'roll50_std',
#   'minute',
#   'hour',
#   'dayofweek',
#   'is_weekend',
#   'is_holiday',
#   'day_off',
#   'hr_sin',
#   'hr_cos']}

# %%
feature_list = loaded_model_dict['feature_names']
model = loaded_model_dict['model']

# %%
# read test data

X_test = pd.read_pickle(data_dir + 'X_test.pkl')

# %%
# limit the data with the feature list

X_pred = X_test[feature_list].head(1)
X_pred
# Out:
#                            roll10_mean  roll10_std  roll20_mean  roll20_std  \
# timestamp
# 2025-11-11 06:10:00+00:00        543.5    3.689324        546.8    4.560702
#
#                            roll50_mean  roll50_std  minute  hour  dayofweek  \
# timestamp
# 2025-11-11 06:10:00+00:00       558.36   12.435565      10     1          1
#
#                            is_weekend  is_holiday  day_off    hr_sin    hr_cos
# timestamp
# 2025-11-11 06:10:00+00:00       False       False    False  0.300706  0.953717

# %%
# predict value

y_pred = model.predict(X_pred)
y_pred
# Out:
# array([541.075])
